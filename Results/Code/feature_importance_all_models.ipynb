# %%
import pandas as pd
import matplotlib.pyplot as plt

rf_data = {
    'Feature': [
        'AwayMomentum','HTR','HomeMomentum','HST','HTAG','HTHG','AST','HomeProb',
        'AwayProb','AvgH','ExpectedGoalDifference','AvgA','DrawProb','AS',
        'TravelDistance','HS','AvgD','HC','HAS','AC','HF','HDS','AF','AAS',
        'Away_Overall','ADS','Home_Overall','HY','AY','AR','HR'
    ],
    'Importance': [
        0.102484, 0.095654, 0.082992, 0.054632, 0.053300, 0.051621, 0.048431,
        0.037512, 0.036299, 0.031619, 0.029606, 0.028532, 0.026693, 0.026103,
        0.025905, 0.024884, 0.024884, 0.023220, 0.020143, 0.019284, 0.018708,
        0.018683, 0.018651, 0.017162, 0.016169, 0.016081, 0.015869, 0.014028,
        0.013915, 0.003790, 0.003145
    ]
}

lr_data = {
    'Feature': [
        'HTHG','HomeMomentum','HST','AvgD','AC','HTR','DrawProb','AR','Away_Overall',
        'AF','HF','AAS','TravelDistance','HDS','Home_Overall','AS','HAS','AwayProb',
        'ExpectedGoalDifference','ADS','HomeProb','HY','AY','AvgA','HC','HR','AvgH',
        'HS','AST','HTAG','AwayMomentum'
    ],
    'Coefficient': [
        0.922716, 0.836426, 0.684150, 0.451766, 0.301596, 0.230781,
        0.208622, 0.179918, 0.074518, 0.074160, 0.054803, 0.044055,
        0.039258, 0.028156, -0.015120, -0.021011, -0.021541, -0.022041,
        -0.022419, -0.030996, -0.032810, -0.069588, -0.087131, -0.118741,
        -0.147646, -0.156157, -0.199344, -0.281236, -0.481807, -0.823647,
        -0.895963
    ]
}

rf_df = pd.DataFrame(rf_data)
lr_df = pd.DataFrame(lr_data)

plt.figure()
rf_df.sort_values('Importance', ascending=True).plot.barh(
    x='Feature', y='Importance', legend=False
)
plt.title('Random Forest Feature Importances')
plt.xlabel('Importance')
plt.tight_layout()

plt.figure()
lr_df.sort_values('Coefficient', ascending=True).plot.barh(
    x='Feature', y='Coefficient', legend=False
)
plt.title('Logistic Regression Feature Coefficients')
plt.xlabel('Coefficient')
plt.tight_layout()
plt.show()
